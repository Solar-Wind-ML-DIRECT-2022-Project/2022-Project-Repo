# %%
# regular imports for the SARIMAX model

import geopandas as gp
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
import numpy as np

# import for checking exogenous variable correlation
from scipy.stats.stats import pearsonr

# %%
filename = 'NASA/POWER_Point_Monthly_Timeseries_1981_2020_048d4093N_123d5716W_LST.json'

df = gp.read_file(filename)

Idict = df['parameter'][0]
Idf =  pd.DataFrame.from_dict(Idict)
Idf
s_index = pd.DataFrame(Idf['ALLSKY_KT'])
#type(s_index)
s_index
# Out:
#         ALLSKY_KT
# 198401       0.43
# 198402       0.39
# 198403       0.47
# 198404       0.48
# 198405       0.48
# ...           ...
# 202009       0.52
# 202010       0.45
# 202011       0.37
# 202012       0.35
# 202013       0.51
#
# [481 rows x 1 columns]

# %%
plt.plot(s_index['ALLSKY_KT'][:])

# %%
def append(dfseries):
    dfseries = dfseries[:4] + '/' + dfseries[4:]
    return dfseries
s_index = s_index.drop(s_index.index[12::13])
s_index['ds']=s_index.index
s_index['ds']= s_index['ds'].astype(str)

s_index['ds'] = s_index['ds'].apply(append)
s_index
# Out:
#         ALLSKY_KT       ds
# 198401       0.43  1984/01
# 198402       0.39  1984/02
# 198403       0.47  1984/03
# 198404       0.48  1984/04
# 198405       0.48  1984/05
# ...           ...      ...
# 202006       0.50  2020/06
# 202007       0.58  2020/07
# 202008       0.62  2020/08
# 202011       0.37  2020/11
# 202012       0.35  2020/12
#
# [350 rows x 2 columns]

# %%
import math

# %%
if math.isnan(s_index['ALLSKY_KT']):
    print(nan)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_24178/2860029993.py in <module>
# ----> 1 if math.isnan(s_index['ALLSKY_KT']):
#       2     print(nan)
#
# ~/miniconda3/envs/SERF/lib/python3.7/site-packages/pandas/core/series.py in wrapper(self)
#     183         if len(self) == 1:
#     184             return converter(self.iloc[0])
# --> 185         raise TypeError(f"cannot convert the series to {converter}")
#     186
#     187     wrapper.__name__ = f"__{converter.__name__}__"
#
# TypeError: cannot convert the series to <class 'float'>

# %%
# Modelling on SARIMAX

model = SARIMAX(s_index['ALLSKY_KT'].values, order=(4,1,0), seasonal_order=(1,1,1,12))
model_fit = model.fit()
# Out:
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -7.50378D-01    |proj g|=  1.41954D+00
#
# At iterate    5    f= -8.30470D-01    |proj g|=  3.46081D+00
#
# At iterate   10    f= -8.74624D-01    |proj g|=  5.14757D-01
#
# At iterate   15    f= -9.09514D-01    |proj g|=  1.78877D-01
#
# At iterate   20    f= -9.13204D-01    |proj g|=  1.62571D-01
#
# At iterate   25    f= -9.18888D-01    |proj g|=  2.32924D-01
#
# At iterate   30    f= -9.40193D-01    |proj g|=  1.67026D-01
#
# At iterate   35    f= -9.62328D-01    |proj g|=  3.62043D-01
#
# At iterate   40    f= -9.78092D-01    |proj g|=  1.08799D-02
#
# At iterate   45    f= -9.79549D-01    |proj g|=  2.77161D-02
#
# At iterate   50    f= -9.79830D-01    |proj g|=  7.01608D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     61      1     0     0   7.016D-03  -9.798D-01
#   F = -0.97982975218474921
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# /home/cbenstead/miniconda3/envs/SERF/lib/python3.7/site-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)

# %%
pred_sol = model_fit.predict(start = 1, end = 600)

# %%
fig, ax = plt.subplots(figsize = (10,8))
ax.plot(s_index['ALLSKY_KT'].values,label = 'real data')
ax.plot(pred_sol, label = 'sarimax')
ax.set_xlabel('month?')
ax.set_ylabel('sol_in (W/m2)')
ax.legend()

# %% [markdown]
# ### Checking the correlation of other variables
#
# I have no idea how to get the sarimax model working so...yeah

# %%
filename = 'NASA/POWER_Point_Monthly_Timeseries_1981_2020_048d4093N_123d5716W_LST.json'

df = gp.read_file(filename)

Idict = df['parameter'][0]
Idf =  pd.DataFrame.from_dict(Idict)

pd_df = pd.DataFrame(Idf)
#type(s_index)
pd_df.head()
# Out:
#         ALLSKY_KT  CLOUD_AMT  CLRSKY_KT  TOA_SW_DWN  ALLSKY_SFC_UVA  \
# 198401       0.43      71.46       0.66        2.80          -999.0
# 198402       0.39      82.41       0.69        4.35          -999.0
# 198403       0.47      76.16       0.72        6.63          -999.0
# 198404       0.48      77.63       0.74        8.97          -999.0
# 198405       0.48      75.46       0.73       10.75          -999.0
#
#         ALLSKY_SFC_UVB  ALLSKY_SRF_ALB  ALLSKY_SFC_SW_DNI  ALLSKY_SFC_SW_DWN  \
# 198401          -999.0            0.23             -999.0               1.20
# 198402          -999.0            0.23             -999.0               1.71
# 198403          -999.0            0.21             -999.0               3.13
# 198404          -999.0            0.16             -999.0               4.30
# 198405          -999.0            0.25             -999.0               5.23
#
#         CLRSKY_SFC_SW_DWN  ALLSKY_SFC_PAR_TOT  ALLSKY_SFC_SW_DIFF  \
# 198401               1.85              -999.0              -999.0
# 198402               2.99              -999.0              -999.0
# 198403               4.76              -999.0              -999.0
# 198404               6.69              -999.0              -999.0
# 198405               7.82              -999.0              -999.0
#
#         CLRSKY_SFC_PAR_TOT  ALLSKY_SFC_UV_INDEX
# 198401              -999.0                 -999
# 198402              -999.0                 -999
# 198403              -999.0                 -999
# 198404              -999.0                 -999
# 198405              -999.0                 -999

# %%
for i in range(len(pd_df)):
    #print(pd_df['CLOUD_AMT'][i])
    if pd_df['TOA_SW_DWN'][i] < 0:
        print([i], 'nan')

# %% [markdown]
# The for loop above checks if there are any unrecorded values in each variable. So far, ``ALLSKY_KT``, ``CLOUD_AMT``, ``CLRSKY_KT``, ``TOA_SW_DWN`` all have values greater than zero (aka recorded values for each month).

# %%
multidf = pd.DataFrame(pd_df[['ALLSKY_KT', 'CLOUD_AMT', 'CLRSKY_KT', 'TOA_SW_DWN']])
multidf.head()
# Out:
#         ALLSKY_KT  CLOUD_AMT  CLRSKY_KT  TOA_SW_DWN
# 198401       0.43      71.46       0.66        2.80
# 198402       0.39      82.41       0.69        4.35
# 198403       0.47      76.16       0.72        6.63
# 198404       0.48      77.63       0.74        8.97
# 198405       0.48      75.46       0.73       10.75

# %%
# removing the 13th month from the df:
multidf = multidf.drop(multidf.index[12::13])

# %%
# renaming ALLSKY_KT to y because this is our main variable
multidf = multidf.rename(columns={"ALLSKY_KT": "y"})

# %%
multidf
# Out:
#            y  CLOUD_AMT  CLRSKY_KT  TOA_SW_DWN
# 198401  0.43      71.46       0.66        2.80
# 198402  0.39      82.41       0.69        4.35
# 198403  0.47      76.16       0.72        6.63
# 198404  0.48      77.63       0.74        8.97
# 198405  0.48      75.46       0.73       10.75
# ...      ...        ...        ...         ...
# 202008  0.62      38.09       0.73        9.52
# 202009  0.52      47.92       0.63        7.34
# 202010  0.45      68.50       0.68        5.01
# 202011  0.37      79.25       0.66        3.17
# 202012  0.35      79.65       0.63        2.37
#
# [444 rows x 4 columns]

# %% [markdown]
# ### Correlation computations
#
# according to the internet, a p-value of less than 0.05 indicates that the value of the coefficient is significant. A negative correlation coeff indicates a negative correlation between the two variables.

# %%
x = multidf['y'].values
y = multidf['CLOUD_AMT'].values

corr , p = pearsonr(x,y)
print ('Correlation Coefficient =', corr,'\nP-Value =',p)
# Out:
# Correlation Coefficient = -0.8746298785117084
# P-Value = 4.488244085486461e-141

# %%
# repeating the process for the other two variables selected

# CLEAR SKY

x = multidf['y'].values
z = multidf['CLRSKY_KT'].values

corr , p = pearsonr(x,z)
print ('Correlation Coefficient =', corr,'\nP-Value =',p)
# Out:
# Correlation Coefficient = 0.72585937880449
# P-Value = 7.719185767030187e-74

# %%
# Top-of-Atmosphere shortwave downward irradiance

x = multidf['y'].values
a = multidf['TOA_SW_DWN'].values

corr , p = pearsonr(x,a)
print ('Correlation Coefficient =', corr,'\nP-Value =',p)
# Out:
# Correlation Coefficient = 0.7528138789467527
# P-Value = 2.6637030138587476e-82

# %%
file = 'POWER_Point_Monthly_Timeseries_1981_2020_047d6664N_122d3020W_LST.json'

data = gp.read_file(file)


Idict = data['parameter'][0]
topd =  pd.DataFrame.from_dict(Idict)
#topd
raindf = pd.DataFrame(topd['PRECTOTCORR'])
#type(s_index)
raindf
# Out:
#         PRECTOTCORR
# 198101         2.54
# 198102         6.39
# 198103         3.00
# 198104         3.70
# 198105         2.15
# ...             ...
# 202009         2.66
# 202010         3.40
# 202011         6.45
# 202012         5.93
# 202013         3.80
#
# [520 rows x 1 columns]

# %%
raindf = raindf.drop(raindf.index[12::13])

# %%
raindf = raindf.loc['198401':]
display(raindf)
# Out:
#         PRECTOTCORR
# 198401         5.08
# 198402         4.49
# 198403         4.31
# 198404         3.59
# 198405         4.26
# ...             ...
# 202008         0.51
# 202009         2.66
# 202010         3.40
# 202011         6.45
# 202012         5.93
#
# [444 rows x 1 columns]

# %%
x = multidf['y'].values
r = raindf['PRECTOTCORR'].values

corr , p = pearsonr(x,r)
print ('Correlation Coefficient =', corr,'\nP-Value =',p)
# Out:
# Correlation Coefficient = -0.8017327311641812
# P-Value = 7.4896144781595e-101

# %%
model = SARIMAX(x, exog=y, order = (6,0,3), seasonal_order = (1,0,1,12))
model_fit = model.fit(disp = False)
# Out:
# /home/cbenstead/miniconda3/envs/SERF/lib/python3.7/site-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)

# %%
predict = model_fit.predict(exog = y, start = 1)

# %%
fig, ax = plt.subplots(figsize = (10,8))
ax.plot(multidf['y'].values,label = 'real data')
ax.plot(predict, label = 'sarimax')
ax.set_xlabel('month?')
ax.set_ylabel('sol_in (W/m2)')
ax.legend()

# %% [markdown]
# ### Creating a forecast/rolling mean thing

# %%
from pandas.tseries.offsets import DateOffset

# %%
new_index = multidf
def append(dfseries):
    dfseries = dfseries[:4] + '-' + dfseries[4:]
    return dfseries

new_index['ds']= new_index.index
new_index['ds']= new_index['ds'].astype(str)
new_index['ds'] = new_index['ds'].apply(append)

newdf = new_index.set_index('ds')

# %%
newdf
# Out:
#             y  CLOUD_AMT  CLRSKY_KT  TOA_SW_DWN  row_num
# ds
# 1984-01  0.43      71.46       0.66        2.80        0
# 1984-02  0.39      82.41       0.69        4.35        1
# 1984-03  0.47      76.16       0.72        6.63        2
# 1984-04  0.48      77.63       0.74        8.97        3
# 1984-05  0.48      75.46       0.73       10.75        4
# ...       ...        ...        ...         ...      ...
# 2020-08  0.62      38.09       0.73        9.52      439
# 2020-09  0.52      47.92       0.63        7.34      440
# 2020-10  0.45      68.50       0.68        5.01      441
# 2020-11  0.37      79.25       0.66        3.17      442
# 2020-12  0.35      79.65       0.63        2.37      443
#
# [444 rows x 5 columns]

# %%
import datetime as dt

# %%
newdf.index = pd.to_datetime(newdf.index)
newdf
# Out:
#                y  CLOUD_AMT  CLRSKY_KT  TOA_SW_DWN  row_num
# ds
# 1984-01-01  0.43      71.46       0.66        2.80        0
# 1984-02-01  0.39      82.41       0.69        4.35        1
# 1984-03-01  0.47      76.16       0.72        6.63        2
# 1984-04-01  0.48      77.63       0.74        8.97        3
# 1984-05-01  0.48      75.46       0.73       10.75        4
# ...          ...        ...        ...         ...      ...
# 2020-08-01  0.62      38.09       0.73        9.52      439
# 2020-09-01  0.52      47.92       0.63        7.34      440
# 2020-10-01  0.45      68.50       0.68        5.01      441
# 2020-11-01  0.37      79.25       0.66        3.17      442
# 2020-12-01  0.35      79.65       0.63        2.37      443
#
# [444 rows x 5 columns]

# %%
type(newdf.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
pred_date=[newdf.index[-1]+ DateOffset(months= x)for x in range(0,24)]

# %%
pred_date = pd.DataFrame(index=pred_date[1:], columns=newdf.columns)
pred_date
# Out:
#               y CLOUD_AMT CLRSKY_KT TOA_SW_DWN row_num
# 2021-01-01  NaN       NaN       NaN        NaN     NaN
# 2021-02-01  NaN       NaN       NaN        NaN     NaN
# 2021-03-01  NaN       NaN       NaN        NaN     NaN
# 2021-04-01  NaN       NaN       NaN        NaN     NaN
# 2021-05-01  NaN       NaN       NaN        NaN     NaN
# 2021-06-01  NaN       NaN       NaN        NaN     NaN
# 2021-07-01  NaN       NaN       NaN        NaN     NaN
# 2021-08-01  NaN       NaN       NaN        NaN     NaN
# 2021-09-01  NaN       NaN       NaN        NaN     NaN
# 2021-10-01  NaN       NaN       NaN        NaN     NaN
# 2021-11-01  NaN       NaN       NaN        NaN     NaN
# 2021-12-01  NaN       NaN       NaN        NaN     NaN
# 2022-01-01  NaN       NaN       NaN        NaN     NaN
# 2022-02-01  NaN       NaN       NaN        NaN     NaN
# 2022-03-01  NaN       NaN       NaN        NaN     NaN
# 2022-04-01  NaN       NaN       NaN        NaN     NaN
# 2022-05-01  NaN       NaN       NaN        NaN     NaN
# 2022-06-01  NaN       NaN       NaN        NaN     NaN
# 2022-07-01  NaN       NaN       NaN        NaN     NaN
# 2022-08-01  NaN       NaN       NaN        NaN     NaN
# 2022-09-01  NaN       NaN       NaN        NaN     NaN
# 2022-10-01  NaN       NaN       NaN        NaN     NaN
# 2022-11-01  NaN       NaN       NaN        NaN     NaN

# %%
newdf =pd.concat([newdf,pred_date])

# %%
b = multidf['y'].values
c = newdf['CLOUD_AMT'].values

model = SARIMAX(b, exog=c, order = (6,0,3), seasonal_order = (1,0,1,12))
model_fit = model.fit(disp = False)
# Out:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# /tmp/ipykernel_24178/2710399790.py in <module>
#       2 c = newdf['CLOUD_AMT'].values
#       3
# ----> 4 model = SARIMAX(b, exog=c, order = (6,0,3), seasonal_order = (1,0,1,12))
#       5 model_fit = model.fit(disp = False)
#
# ~/miniconda3/envs/SERF/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py in __init__(self, endog, exog, order, seasonal_order, trend, measurement_error, time_varying_regression, mle_regression, simple_differencing, enforce_stationarity, enforce_invertibility, hamilton_representation, concentrate_scale, trend_offset, use_exact_diffuse, dates, freq, missing, validate_specification, **kwargs)
#     330             trend=trend, enforce_stationarity=None, enforce_invertibility=None,
#     331             concentrate_scale=concentrate_scale, dates=dates, freq=freq,
# --> 332             missing=missing, validate_specification=validate_specification)
#     333         self._params = SARIMAXParams(self._spec)
#     334
#
# ~/miniconda3/envs/SERF/lib/python3.7/site-packages/statsmodels/tsa/arima/specification.py in __init__(self, endog, exog, order, seasonal_order, ar_order, diff, ma_order, seasonal_ar_order, seasonal_diff, seasonal_ma_order, seasonal_periods, trend, enforce_stationarity, enforce_invertibility, concentrate_scale, trend_offset, dates, freq, missing, validate_specification)
#     445         # providing us with a time series index
#     446         self._model = TimeSeriesModel(endog, exog=exog, dates=dates, freq=freq,
# --> 447                                       missing=missing)
#     448         self.endog = None if faux_endog else self._model.endog
#     449         self.exog = self._model.exog
#
# ~/miniconda3/envs/SERF/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py in __init__(self, endog, exog, dates, freq, missing, **kwargs)
#     466         self, endog, exog=None, dates=None, freq=None, missing="none", **kwargs
#     467     ):
# --> 468         super().__init__(endog, exog, missing=missing, **kwargs)
#     469
#     470         # Date handling in indexes
#
# ~/miniconda3/envs/SERF/lib/python3.7/site-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#     265
#     266     def __init__(self, endog, exog=None, **kwargs):
# --> 267         super().__init__(endog, exog, **kwargs)
#     268         self.initialize()
#     269
#
# ~/miniconda3/envs/SERF/lib/python3.7/site-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#      91         hasconst = kwargs.pop('hasconst', None)
#      92         self.data = self._handle_data(endog, exog, missing, hasconst,
# ---> 93                                       **kwargs)
#      94         self.k_constant = self.data.k_constant
#      95         self.exog = self.data.exog
#
# ~/miniconda3/envs/SERF/lib/python3.7/site-packages/statsmodels/base/model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#     130
#     131     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 132         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     133         # kwargs arrays could have changed, easier to just attach here
#     134         for key in kwargs:
#
# ~/miniconda3/envs/SERF/lib/python3.7/site-packages/statsmodels/base/data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     672     klass = handle_data_class_factory(endog, exog)
#     673     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
# --> 674                  **kwargs)
#
# ~/miniconda3/envs/SERF/lib/python3.7/site-packages/statsmodels/base/data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      84         self.const_idx = None
#      85         self.k_constant = 0
# ---> 86         self._handle_constant(hasconst)
#      87         self._check_integrity()
#      88         self._cache = {}
#
# ~/miniconda3/envs/SERF/lib/python3.7/site-packages/statsmodels/base/data.py in _handle_constant(self, hasconst)
#     130             exog_max = np.max(self.exog, axis=0)
#     131             if not np.isfinite(exog_max).all():
# --> 132                 raise MissingDataError('exog contains inf or nans')
#     133             exog_min = np.min(self.exog, axis=0)
#     134             const_idx = np.where(exog_max == exog_min)[0].squeeze()
#
# MissingDataError: exog contains inf or nans
